# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios funciones
# ## Ejercicio 1
# Escribe una función que convierta números del 1 al 7 en nombres de los dias de la semana. La función constará de un único argumento numérico y una salida de tipo string

# %%
def dia_semana(numero):
    dias = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
    for x in dias:
        return dias[numero - 1]      # El formato de abajo está mirado en internet, este de aquí arriba se me ha ocurrido a mi a raíz del otro, sin embargo no se cubre de números inválidos.

# %%
dia_semana(4)
# Out:
# 'Jueves'

# %%
def dia_semana(numero):
    dias = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
    if 1 <= numero <= 7:
        return dias[numero - 1]
    else:
        return "Número inválido"

# %%
dia_semana(2)
# Out:
# 'Martes'

# %% [markdown]
# ## Ejercicio 2
# En el ejercicio 8 de flujos de control, creábamos una pirámide invertida de números desde el 5. Crea una función que replique el comportamiento de la pirámide, y utiliza un único parámetro de entrada de la función para determinar el número de filas de la pirámide.

# %%
def piramide_invertida(filas):
    for i in range(filas, 0, -1):
        for j in range(i, 0, -1):
            print(j, end=" ")                # Esto no se hacerlo directamente. Aún estando enfermo he atendido a toda la clase pero tengo la cabeza hecha un desastre.
        print()                              # Está sacado de internet pero directamente no lo entiendo.

# %%
piramide_invertida(5)
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %% [markdown]
# ## Ejercicio 3
# Escribe una función que compare dos números. La función tiene dos argumentos y hay tres salidas posibles: que sean iguales, que el primero sea  mayor que el segundo, o que el segundo sea mayor que el primero

# %%
def comparacion(x, y):
    if x == y:
        return "Son iguales"
    elif x > y:
        return "El primero es mayor que el segundo"           # Este si he sabido hacerlo yo con bastante facilidad, pero los de antes no los entiendo demasiado.
    elif y > x:
        return "El segundo es mayor que el primero"

# %%
comparacion(5, 3)
# Out:
# 'El primero es mayor que el segundo'

# %% [markdown]
# ## Ejercicio 4
# Escribe una función que sea un contador de letras. En el primer argumento tienes que introducir un texto, y el segundo que sea una letra que contar. La función tiene que devolver un entero con el número de veces que aparece esa letra, tanto mayúscula, como minúscula

# %%
def contador(palabra, letra):     # Esto también lo he conseguido hacer, me he dado cuenta que si pongo mayúsuclas no las encuentra, así que las convierto todas en lower.
    numero = 0
    for x in palabra:
        if x == letra:
            numero = numero + 1   # No he conseguido hacer la conversión a lower de las variables, pero bueno, funciona mas o menos bien.
    return numero

# %%
contador("hacienda", "h")
# Out:
# 1

# %% [markdown]
# ## Ejercicio 5
# Escribe una función que tenga un único argumento, un string. La salida de la función tiene que ser un diccionario con el conteo de todas las letras de ese string, siendo la clave la letra y el valor el conteo.

# %%
def diccionario_1(string):
    return {letra: i + 1 for i, letra in enumerate(string)}    # Lo entiendo a medias, yo estaba intentando definir un diccionario vacío y luego ir añadiendo entradas, pero no lo conseguía, está intentado abajo.

# %%
diccionario_1("Jacinto")
# Out:
# {'J': 1, 'a': 2, 'c': 3, 'i': 4, 'n': 5, 't': 6, 'o': 7}

# %%
def diccionario_2(string):
    diccionario_variable = {}
    for x, y in enumerate(string):
        diccionario_variable.update({x + 1 : y})     # Pero no consigo que me imprima toda la palabra entera...
        return diccionario_variable                  # ¿A lo mejor es porque el return está dentro del bucle? Para que tengan sentido estos comentarios lo vuelvo a intentar mas abajo.

# %%
diccionario_2("Manuel")
# Out:
# {1: 'M'}

# %%
def diccionario_2(string):
    diccionario_variable = {}
    for x, y in enumerate(string):
        diccionario_variable.update({x + 1 : y})
    return diccionario_variable   # Pruebo con el return mas atrás.

# %%
diccionario_2("Manuel")       # Olé
# Out:
# {1: 'M', 2: 'a', 3: 'n', 4: 'u', 5: 'e', 6: 'l'}

# %% [markdown]
# ## Ejercicio 6
# Escribir una función que añada o elimine elementos en una lista. La función necesita los siguientes argumentos:
# * lista: la lista donde se añadirán o eliminarán los elementos
# * comando: "add" o "remove"
# * elemento: Por defecto es None.
#
# Tendrá como salida la lista

# %%
def modificar_lista(lista, comando, elemento=None):
    if comando == "add":
        lista.append(elemento)
    elif comando == "remove" and elemento in lista:
        lista.remove(elemento)
    return lista

# %%
modificar_lista([1,2,3,4,5], "remove", 3)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# ## Ejercicio 7
# Crea una función que reciba un número arbitrario de palabras, y devuelva una frase completa, separando las palabras con espacios.

# %%
def hacedor_de_frases_xd(*args):
    for x in args:
        return " ".join(args)   # Olé.

# %%
hacedor_de_frases_xd("Hola", "me", "llamo", "Carlos")
# Out:
# 'Hola me llamo Carlos'

# %% [markdown]
# ## Ejercicio 8
# Escribe un programa que obtenga el enésimo número de la [serie de Fibonacci](https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci). Tienes que crear una función recursiva con un único argumento.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21
# ```

# %% [markdown]
# fibonacci(n) = fibonacci(n-1) + fibonacci(n-2)

# %%
# Buah, ni idea.

# %% [markdown]
# ## Ejercicio 9
# Define en una única celda las siguientes funciones:
# * Función que calcule el área de un cuadrado
# * Función que calcule el área de un triángulo
# * Función que calcule el área de un círculo
#
# En otra celda, calcular el area de:
# * Dos círculos de radio 10 + un triángulo de base 3 y altura 7
# * Un cuadrado de lado = 10 + 3 círculos (uno de radio = 4 y los otros dos de radio = 6) + 5 triángulos de base = 2 + altura = 4

# %%
import math

def area_cua(lado):
    return lado * lado
def area_tri(base, altura):
    return base * altura / 2
def area_cir(radio):
    return math.pi * radio * radio

# %%
print((area_cir(10) * 2) + area_tri(3, 7))

print(area_cua(10) + area_cir(4) + (area_cir(6) * 2) + (area_tri(2, 4) * 5))         # Olé.
# Out:
# 638.8185307179587
# 396.46015351590177

# %% [markdown]
# ## Ejercicio 10
#
# Guarda las funciones de estos ejercicios en un fichero llamado `funciones.py` e importalas desde este jupyter notebook para probar que puedes hacer uso de ellas.

# %%
# No se hacerlo, y ha sido un día muy complicado gran parte en cama. Pero mañana a ver si lo entiendo todo mejor.
