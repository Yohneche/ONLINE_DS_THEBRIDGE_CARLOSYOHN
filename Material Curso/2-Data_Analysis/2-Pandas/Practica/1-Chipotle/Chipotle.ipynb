# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep="\t")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
mas_caro = chipo.loc[chipo['item_price'].idxmax(), 'item_name']

print(mas_caro)
# Out:
# Steak Salad Bowl

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
contador = 0

for mas10 in chipo['item_price']:
    if mas10 > 10:
        contador += 1

print(contador)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 contador = 0
#       3 for mas10 in chipo['item_price']:
# ----> 4     if mas10 > 10:
#       5         contador += 1
#       7 print(contador)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### Step 4.1: Y cuántos pedidos se han hecho con un producto de más de 10$? Es lo mismo?

# %%
filtro = chipo[chipo['item_price'] > 10]

num_pedidos = filtro['order_id'].nunique()

print(num_pedidos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 filtro = chipo[chipo['item_price'] > 10]
#       3 num_pedidos = filtro['order_id'].nunique()
#       5 print(num_pedidos)
#
# File c:\Users\charl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\charl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# ...

# %% [markdown]
# ### Step 4.2: Y cuántos pedidos se han hecho de más de 10$? Es lo mismo?

# %%
total_pedidos = chipo.groupby('order_id')['item_price'].sum()
pedidos_mas_10 = (total_pedidos > 10).sum()

print(pedidos_mas_10)
# Out:
# 1834

# %% [markdown]
# ### Step 4.3: Y en cuántos pedidos se ha pagado más de 10$ por un mismo producto? Es lo mismo?

# %%
filtro = chipo[chipo['item_price'] > 10]
pedidos_producto_10 = filtro['order_id'].nunique()

print(pedidos_producto_10)
# Out:
# 863

# %% [markdown]
# ### Step 5. What is the price of each item and name it unit_price. Get only item_name and unit_price

# %%
chipo['unit_price'] = chipo['item_price'] / chipo['quantity']
chipo[['item_name', 'unit_price']].head()
# Out:
#                                item_name  unit_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl        8.49

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo_sorted = chipo.sort_values(by='item_name')
chipo_sorted
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
indice_max = chipo['item_price'].idxmax()
cantidad_max = chipo.loc[indice_max, 'quantity']

print(cantidad_max)
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?
