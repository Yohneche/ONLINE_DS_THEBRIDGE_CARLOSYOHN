# %%
import pandas as pd

# %%
videojuegos = pd.read_csv("Data/dato.csv")

# %%
videojuegos
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %%
videojuegos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Platform            7112 non-null   object
#  1   Genre               7112 non-null   object
#  2   Publisher           7112 non-null   object
#  3   NA_Sales            7112 non-null   object
#  4   EU_Sales            7112 non-null   object
#  5   JP_Sales            7112 non-null   object
#  6   Other_Sales         7112 non-null   object
#  7   Global_Sales        7112 non-null   object
#  8   Rating              7112 non-null   object
#  9   Critic_Score_Class  7112 non-null   object
# dtypes: object(10)
# memory usage: 555.8+ KB

# %%
videojuegos.describe()
# Out:
#        Platform   Genre        Publisher NA_Sales EU_Sales JP_Sales  \
# count      7112    7112             7112     7112     7112     7112
# unique       17      12              278      349      272      160
# top         PS2  Action  Electronic Arts        0        0        0
# freq       1169    1698              971      642     1015     5052
#
#        Other_Sales Global_Sales Rating Critic_Score_Class
# count         7112         7112   7112               7112
# unique         147          542      7                  4
# top           0,01         0,02      T          Excelente
# freq          1575          221   2489               1997

# %%
videojuegos.columns
# Out:
# Index(['Platform', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales',
#        'Other_Sales', 'Global_Sales', 'Rating', 'Critic_Score_Class'],
#       dtype='object')

# %%
videojuegos["EU_Sales"].idxmax()
# Out:
# 12

# %%
videojuegos[10:13]
# Out:
#    Platform   Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 10      PS3  Action  Take-Two Interactive     7,02     9,14     0,98
# 11      PS2  Action  Take-Two Interactive     9,43      0,4     0,41
# 12       DS    Misc              Nintendo     4,74      9,2     4,16
#
#    Other_Sales Global_Sales Rating Critic_Score_Class
# 10        3,97        21,12      M          Excelente
# 11       10,57        20,81      M          Excelente
# 12        2,04        20,15      E              Bueno

# %%
videojuegos["Platform"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Wii
# 1       Wii
# 2       Wii
# 3        DS
# 4       Wii
#        ...
# 7107     PC
# 7108     PC
# 7109     PC
# 7110     PC
# 7111    PS4
# Name: Platform, Length: 7112, dtype: object>

# %%
videojuegos.value_counts(["Platform"])
# Out:
# Platform
# PS2         1169
# X360         888
# PS3          790
# PC           734
# X            586
# Wii          493
# DS           472
# PSP          401
# GC           363
# PS4          255
# GBA          249
# XOne         169
# 3DS          161
# PS           154
# PSV          125
# WiiU          89
# DC            14
# Name: count, dtype: int64

# %%
videojuegos.loc[videojuegos["Platform"] == "PS3", "EU_Sales"]
# Out:
# 10      9,14
# 19      5,73
# 23      5,73
# 27      4,37
# 35      4,82
#         ...
# 7014    0,01
# 7030    0,01
# 7064    0,01
# 7070       0
# 7071    0,01
# Name: EU_Sales, Length: 790, dtype: object

# %%
import pandas as pd

videojuegos = pd.read_csv("Data/Video_Games_Sales_as_at_22_Dec_2016.csv")

# %%
ps4_sales = pd.read_csv("Data/PS4sales.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ps4_sales = pd.read_csv("Data/PS4sales.csv")
#
# File c:\Users\charl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
videojuegos
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...
